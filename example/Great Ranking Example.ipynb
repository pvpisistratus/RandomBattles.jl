# %%
#using Pkg; Pkg.add(PackageSpec(url="https://github.com/pvpisistratus/RandomBattles.jl", rev="master"))
using RandomBattles, DataFrames, Plots

# %%
df = rank(35, "your-frequency-file-great.csv", "great-ranking.csv", league = "great");
# Out:
# Constructing Empirical Teams...
# ┌ Warning: Ignoring team aerodactyl, charmander, diglett
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team xatu, spheal, charmander
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team venusaur, primeape, togepi
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team claydol, minccino, galvantula
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team bidoof, swinub, magikarp
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team magikarp, horsea, caterpie
# └ @ RandomBattles /home/pisistratus/.julia/packages/RandomBattles/UhgMA/src/rankings.jl:18
# ┌ Warning: Ignoring team whiscash, oshawott, stantler
# ...

# %%
histogram(df[1], xlims = [0, 5])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[4]:1
# └ @ Core In[4]:1
